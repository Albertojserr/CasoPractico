# %%
import dask.dataframe as dd
import matplotlib.pyplot as plt

# %%
datos=dd.read_csv("creditcard.csv", assume_missing=True)

# %%
datos.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
datos["Class"].value_counts().compute()
# Out:
# 0.0    284315
# 1.0       492
# Name: Class, dtype: int64

# %%
datos["Class"].value_counts().compute().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
normales = datos[datos.Class==0]
fraudulentos = datos[datos.Class==1]
plt.scatter(normales.Time.compute()/3600, normales.Amount.compute(), 
    alpha = 0.5, c='#19323C', label='Normales', s=3)
plt.scatter(fraudulentos.Time.compute()/3600, fraudulentos.Amount.compute(), 
    alpha = 0.5, c='#F2545B', label='Fraudulentos', s=3)
plt.xlabel('Tiempo desde la primera transacción (h)')
plt.ylabel('Monto (Euros)')
plt.legend(loc='upper right')
plt.show()

# %%
import matplotlib.gridspec as gridspec
import seaborn as sns

v_1_28 = datos.iloc[:,1:29].columns
gs = gridspec.GridSpec(28, 1)
for i, cn in enumerate(datos[v_1_28]):
    sns.distplot(datos[cn][datos.Class == 1].compute(), bins=50, 
        label='Fraudulentos', color='#F2545B')
    sns.distplot(datos[cn][datos.Class == 0].compute(), bins=50, 
        label='Normales', color='#19323C')
    plt.xlabel('')
    plt.title('Histograma característica: ' + str(cn))
    plt.legend(loc='upper right')
    plt.show()
# Out:
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/alberto/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.gridspec as gridspec
import seaborn as sns
import statsmodels.api as sm
import numpy as np
v_1_28 = datos.iloc[:,1:29].columns
gs = gridspec.GridSpec(28, 1)
for i, cn in enumerate(datos[v_1_28]):
    fig = plt.figure(figsize=(12, 5))
    ax = fig.add_subplot(111)
    validos=datos[cn][datos.Class == 0]
    fraudulentos=datos[cn][datos.Class == 0]
    kde=sm.nonparametric.KDEUnivariate(validos)
    kde1=sm.nonparametric.KDEUnivariate(fraudulentos)
    
    weights=np.ones_like(validos)/len(validos)
    weights1=np.ones_like(fraudulentos)/len(fraudulentos)
    # Scatter plot of data samples and histogram
    
    ax.hist(validos,weights=weights, alpha=0.2, bins=50, color="k", label="Validos",density=True)
    ax.hist(fraudulentos,weights=weights1, alpha=0.2, bins=50, color="r", label="Fraudulentos",density=False)
    
    # Plot the true distribution
    
    kde.fit(bw=1)
    kde1.fit(bw=1)
    ax.plot(kde.support, kde.density, "-",lw=2, color="k", zorder=10)
    ax.plot(kde1.support, kde1.density, "-",lw=2, color="r",zorder=10)
        
    ax.legend(loc="best")
    ax.grid(True, zorder=-5)
# Out:
# <ipython-input-9-d40da0bdec3a>:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=(12, 5))

# %% [markdown]
# Como podemos ver con las curvas, no difieren la de los datos validos y la de los fraudulentos por lo que no podemos separar los datos

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
datos = pd.read_csv("creditcard.csv")
datos.drop(['Time'], axis=1, inplace=True)
datos['Amount'] = StandardScaler().fit_transform(datos['Amount'].values.reshape(-1,1))

from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(datos, test_size=0.2, random_state=42)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)
X_train = X_train.values

Y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)
X_test = X_test.values

# %%
np.random.seed(5)
from keras.models import Model, load_model
from keras.layers import Input, Dense

dim_entrada = X_train.shape[1]          # 29
capa_entrada = Input(shape=(dim_entrada,))

encoder = Dense(20, activation='tanh')(capa_entrada)
encoder = Dense(14, activation='relu')(encoder)

decoder = Dense(20, activation='tanh')(encoder)
decoder = Dense(29, activation='relu')(decoder)

autoencoder = Model(inputs=capa_entrada, outputs=decoder)

from keras.optimizers import SGD
sgd = SGD(lr=0.01)
autoencoder.compile(optimizer='sgd', loss='mse')

nits = 100
tam_lote = 32
autoencoder.fit(X_train, X_train, epochs=nits, batch_size=tam_lote, shuffle=True, validation_data=(X_test,X_test), verbose=1)
# Out:
# /home/alberto/anaconda3/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.9046 - val_loss: 0.8570
# Epoch 2/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.8041 - val_loss: 0.8146
# Epoch 3/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7737 - val_loss: 0.7928
# Epoch 4/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7551 - val_loss: 0.7773
# Epoch 5/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7401 - val_loss: 0.7633
# Epoch 6/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7262 - val_loss: 0.7507
# Epoch 7/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7142 - val_loss: 0.7384
# Epoch 8/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7023 - val_loss: 0.7270
# Epoch 9/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6911 - val_loss: 0.7158
# Epoch 10/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6814 - val_loss: 0.7071
# Epoch 11/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6734 - val_loss: 0.7003
# Epoch 12/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6672 - val_loss: 0.6953
# Epoch 13/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6627 - val_loss: 0.6912
# Epoch 14/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6590 - val_loss: 0.6881
# Epoch 15/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6558 - val_loss: 0.6853
# Epoch 16/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6530 - val_loss: 0.6827
# Epoch 17/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6504 - val_loss: 0.6810
# Epoch 18/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6482 - val_loss: 0.6784
# Epoch 19/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6461 - val_loss: 0.6764
# Epoch 20/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6444 - val_loss: 0.6755
# Epoch 21/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6429 - val_loss: 0.6734
# Epoch 22/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6415 - val_loss: 0.6721
# Epoch 23/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6403 - val_loss: 0.6713
# Epoch 24/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6391 - val_loss: 0.6794
# Epoch 25/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6377 - val_loss: 0.6688
# Epoch 26/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6363 - val_loss: 0.6674
# Epoch 27/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6354 - val_loss: 0.6669
# Epoch 28/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6345 - val_loss: 0.6662
# Epoch 29/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6338 - val_loss: 0.6652
# Epoch 30/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6330 - val_loss: 0.6646
# Epoch 31/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6325 - val_loss: 0.6640
# Epoch 32/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6319 - val_loss: 0.6633
# Epoch 33/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6313 - val_loss: 0.6631
# Epoch 34/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6308 - val_loss: 0.6628
# Epoch 35/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6303 - val_loss: 0.6623
# Epoch 36/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6298 - val_loss: 0.6615
# Epoch 37/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6294 - val_loss: 0.6609
# Epoch 38/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6291 - val_loss: 0.6604
# Epoch 39/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6286 - val_loss: 0.6602
# Epoch 40/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6282 - val_loss: 0.6598
# Epoch 41/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6279 - val_loss: 0.6594
# Epoch 42/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6276 - val_loss: 0.6592
# Epoch 43/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6273 - val_loss: 0.6592
# Epoch 44/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6274 - val_loss: 0.6593
# Epoch 45/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6266 - val_loss: 0.6587
# Epoch 46/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6266 - val_loss: 0.6579
# Epoch 47/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6262 - val_loss: 0.6623
# Epoch 48/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6259 - val_loss: 0.6590
# Epoch 49/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6263 - val_loss: 0.6578
# Epoch 50/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6255 - val_loss: 0.6569
# Epoch 51/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6252 - val_loss: 0.6568
# Epoch 52/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6249 - val_loss: 0.6568
# Epoch 53/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6246 - val_loss: 0.6568
# Epoch 54/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6251 - val_loss: 0.6574
# Epoch 55/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6247 - val_loss: 0.6569
# Epoch 56/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6242 - val_loss: 0.6558
# Epoch 57/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6244 - val_loss: 0.6563
# Epoch 58/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6238 - val_loss: 0.6567
# Epoch 59/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6237 - val_loss: 0.6551
# Epoch 60/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6234 - val_loss: 0.6559
# Epoch 61/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6231 - val_loss: 0.6548
# Epoch 62/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6229 - val_loss: 0.6547
# Epoch 63/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6229 - val_loss: 0.6546
# Epoch 64/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6231 - val_loss: 0.6554
# Epoch 65/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6225 - val_loss: 0.6555
# Epoch 66/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6224 - val_loss: 0.6541
# Epoch 67/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6221 - val_loss: 0.6555
# Epoch 68/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6220 - val_loss: 0.6539
# Epoch 69/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6221 - val_loss: 0.6543
# Epoch 70/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6217 - val_loss: 0.6534
# Epoch 71/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6216 - val_loss: 0.6539
# Epoch 72/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6214 - val_loss: 0.6535
# Epoch 73/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6213 - val_loss: 0.6531
# Epoch 74/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6244 - val_loss: 0.6546
# Epoch 75/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6211 - val_loss: 0.6529
# Epoch 76/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6208 - val_loss: 0.6529
# Epoch 77/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6206 - val_loss: 0.6528
# Epoch 78/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6205 - val_loss: 0.6525
# Epoch 79/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6203 - val_loss: 0.6528
# Epoch 80/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6206 - val_loss: 0.6528
# Epoch 81/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6203 - val_loss: 0.6525
# Epoch 82/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6212 - val_loss: 0.6522
# Epoch 83/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6202 - val_loss: 0.6524
# Epoch 84/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6199 - val_loss: 0.6534
# Epoch 85/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6197 - val_loss: 0.6523
# Epoch 86/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6198 - val_loss: 0.6523
# Epoch 87/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6198 - val_loss: 0.6526
# Epoch 88/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6194 - val_loss: 0.6515
# Epoch 89/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6207 - val_loss: 0.6584
# Epoch 90/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6205 - val_loss: 0.6520
# Epoch 91/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6189 - val_loss: 0.6513
# Epoch 92/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6187 - val_loss: 0.6510
# Epoch 93/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6189 - val_loss: 0.6511
# Epoch 94/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6205 - val_loss: 0.6534
# Epoch 95/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6187 - val_loss: 0.6536
# Epoch 96/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6190 - val_loss: 0.6511
# Epoch 97/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6185 - val_loss: 0.6533
# Epoch 98/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6187 - val_loss: 0.6524
# Epoch 99/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6183 - val_loss: 0.6505
# Epoch 100/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6180 - val_loss: 0.6504

# %%
X_pred = autoencoder.predict(X_test)
ecm = np.mean(np.power(X_test-X_pred,2), axis=1)
print(X_pred.shape)

# Gráfica precision-recall para determinar el umbral
from sklearn.metrics import confusion_matrix, precision_recall_curve
precision, recall, umbral = precision_recall_curve(Y_test, ecm)

plt.plot(umbral, precision[1:], label="Precision",linewidth=5)
plt.plot(umbral, recall[1:], label="Recall",linewidth=5)
plt.title('Precision y Recall para diferentes umbrales')
plt.xlabel('Umbral')
plt.ylabel('Precision/Recall')
plt.legend()
plt.show()
# Out:
# 1781/1781 [==============================] - 2s 1ms/step
# (56962, 29)

# %%
umbral_fijo = 0.75
Y_pred = [1 if e > umbral_fijo else 0 for e in ecm]

conf_matrix = confusion_matrix(Y_test, Y_pred)
print(conf_matrix)
# Out:
# [[49423  7441]
#  [    7    91]]
